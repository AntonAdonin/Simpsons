# %%
import hashlib
import os
import sys
from glob import glob
from pathlib import Path
print(os.listdir())
import math
import matplotlib.pyplot as plt
import torch
from PIL import Image
import torchvision.datasets as datasets
from torchvision import transforms
import torchvision
from tqdm import tqdm
import numpy as np
# Out:
# ['.DS_Store', 'train_dir', 'requirements.txt', 'simpsons-using-pytorch.ipynb', 'prepare_data.ipynb', 'characters_illustration.png', '.gitignore', 'test_dir', 'number_pic_char.csv', '.ipynb_checkpoints', 'venv', 'annotation.txt', '.git', 'main.py', 'Архив.zip', '.idea']

# %%
train_dir = Path('./train_dir/simpsons_dataset/')
test_dir = Path('./test_dir/kaggle_simpson_testset/')


def list_of_train_files(with_aug=True):
    filename = '*/*.jpg'
    if with_aug:
        filename = '*/*.*'
    files_training = glob(os.path.join(train_dir, filename))
    print('Number of images in Training dir:', len(files_training))
    return files_training


list_of_train_files()
# Out:
# Number of images in Training dir: 31015
# ['train_dir/simpsons_dataset/maggie_simpson/random_aug_pic346.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic420.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic434.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0028.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic352.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0000.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0014.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic408.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic385.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic391.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic144.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic150.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic178.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic187.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic193.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic232.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic226.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic227.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic233.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic192.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic186.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic179.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic151.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic145.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic390.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic384.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic409.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0015.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0001.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0029.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic435.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic353.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic347.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic421.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic351.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic437.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic423.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic345.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0017.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0003.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic379.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic392.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic386.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic153.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic147.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic190.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic184.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic225.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic231.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic219.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic218.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic230.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic224.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic185.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic191.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic146.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic152.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic387.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic393.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0002.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic378.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0016.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic422.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic344.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic350.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic436.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0012.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic368.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0006.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic432.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic354.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic340.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic426.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic397.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic383.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic156.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic142.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic195.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic181.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic208.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic220.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic234.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic235.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic221.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic209.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic180.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic194.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic143.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic157.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic382.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic396.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic341.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic427.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic433.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic355.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0007.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0013.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic369.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0005.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic419.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0011.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic425.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0039.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic343.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic357.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic431.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic380.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic394.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic169.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic141.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic155.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic182.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic196.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic237.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic223.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic222.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic236.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic197.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic183.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic154.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic140.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic168.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic395.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic381.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic356.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic430.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0038.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic424.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic342.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0010.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic418.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0004.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic443.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic325.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic331.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic457.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0063.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic319.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0077.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic480.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0088.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic494.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic133.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic251.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic245.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0117.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic279.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0103.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic292.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic286.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic287.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic293.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic278.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0102.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0116.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic244.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic250.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic132.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic495.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0089.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic481.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0076.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0062.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic318.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic330.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic456.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic442.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic324.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic454.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0048.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic332.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic326.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic440.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0074.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic468.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0060.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic497.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic483.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic130.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic246.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic252.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0100.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0114.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic285.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic291.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic290.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic284.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0115.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0101.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic253.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic247.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic131.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic482.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic496.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0061.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic469.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0075.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic327.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic441.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0049.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic455.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic333.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0071.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0065.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic479.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic337.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic451.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic445.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0059.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic323.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic492.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic486.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic135.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0105.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0111.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic243.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic257.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic280.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic294.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic295.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic281.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic256.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic242.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0110.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0104.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic134.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic487.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic493.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0058.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic444.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic322.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic336.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic450.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic478.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0064.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0070.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0066.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0072.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic308.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic320.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic446.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic452.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic334.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0099.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic485.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic491.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic136.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic268.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0112.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0106.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic254.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic240.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic297.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic283.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic282.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic296.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic241.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic255.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0107.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic269.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0113.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic137.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic490.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic484.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0098.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic453.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic335.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic321.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic447.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0073.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic309.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0067.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic462.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic304.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic310.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic476.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0042.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic338.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0056.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0081.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic489.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0095.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic270.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic264.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic502.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic258.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0122.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic259.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0123.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic265.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic271.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0094.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic488.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0080.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0057.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0043.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic339.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic311.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic477.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic463.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic305.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic475.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0069.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic313.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic307.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic461.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0055.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic449.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0041.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0096.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0082.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic139.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic501.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic267.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic273.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0109.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0121.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic298.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic299.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0120.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic272.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0108.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic500.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic266.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic138.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0083.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0097.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0040.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic448.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0054.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic306.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic460.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0068.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic474.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic312.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0050.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0044.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic458.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic316.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic470.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic464.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0078.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic302.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0093.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0087.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic128.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0124.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic262.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0118.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic276.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic289.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic288.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic277.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic263.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0119.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0125.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic129.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0086.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0092.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0079.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic465.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic303.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic317.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic471.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic459.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0045.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0051.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0047.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0053.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic329.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic301.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic467.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic473.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic315.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic498.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0084.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0090.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic249.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0127.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic275.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic261.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic260.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic274.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0126.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic248.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0091.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0085.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic499.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic472.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic314.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic300.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic466.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0052.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic328.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0046.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic367.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic401.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic415.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0009.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic373.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0021.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0035.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic429.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic398.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic165.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic171.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic159.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic213.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic207.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic206.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic212.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic158.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic170.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic164.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic399.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic428.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0034.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0020.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0008.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic414.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic372.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic366.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic400.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic370.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic416.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic402.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic364.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0036.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0022.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic358.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic172.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic166.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic199.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic204.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic210.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic238.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic239.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic211.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic205.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic198.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic167.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic173.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0023.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic359.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0037.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic403.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic365.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic371.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic417.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0033.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic349.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0027.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic413.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic375.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic361.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic407.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic177.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic163.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic188.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic229.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic201.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic215.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic214.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic200.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic228.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic189.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic162.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic176.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic360.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic406.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic412.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic374.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0026.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0032.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic348.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0024.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic438.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0030.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic404.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0018.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic362.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic376.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic410.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic389.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic148.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic160.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic174.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic216.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic202.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic203.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic217.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic175.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic161.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic149.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic388.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic377.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic411.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0019.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic405.png',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic363.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0031.jpg',
#  'train_dir/simpsons_dataset/maggie_simpson/random_aug_pic439.png',
#  'train_dir/simpsons_dataset/maggie_simpson/pic_0025.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0982.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0028.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0996.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0766.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0000.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0014.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0772.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0941.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0799.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0955.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0969.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1120.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0558.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1134.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0202.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0564.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0570.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0216.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1108.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1054.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0438.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1040.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1068.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0376.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0410.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0404.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0362.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0389.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1097.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1083.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0148.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0612.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0174.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0160.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0606.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0835.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0821.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0809.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0808.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0820.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0834.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0161.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0607.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0613.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0175.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0149.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1082.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1096.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0388.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0405.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0363.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0377.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1069.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0411.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0439.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1041.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1055.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0571.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1109.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0217.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0203.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0565.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1135.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1121.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0559.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0968.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0954.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0798.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0940.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0015.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0773.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0767.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0001.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0029.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0997.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0983.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0995.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0759.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0981.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0771.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0017.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0003.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0765.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0956.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0942.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0229.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1137.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1123.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0215.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0573.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0567.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0201.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0598.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1043.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1057.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0349.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0361.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0407.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0413.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0375.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1080.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1094.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0639.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0605.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0163.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0177.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0611.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0822.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0188.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0836.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0189.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0837.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0823.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0176.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0610.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0604.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0162.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0638.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1095.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1081.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0412.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0374.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0360.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0406.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0348.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1056.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1042.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0599.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0566.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0200.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0214.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0572.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1122.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1136.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0228.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0943.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0957.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0002.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0764.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0770.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0016.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0980.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0758.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0994.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0012.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0774.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0760.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0006.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0748.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0990.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0984.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0953.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0947.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0576.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0210.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0204.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0562.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1132.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0238.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1126.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0589.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0402.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0364.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0370.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0416.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1046.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0358.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1052.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1085.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1091.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0166.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0600.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0614.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0172.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0628.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0199.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0827.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0833.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0832.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0198.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0826.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0629.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0615.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0173.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0167.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0601.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1090.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1084.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1053.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0359.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1047.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0371.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0417.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0403.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0365.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0588.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1127.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0239.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1133.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0205.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0563.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0577.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0211.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0946.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0952.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0985.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0991.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0749.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0761.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0007.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0013.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0775.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0005.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0763.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0777.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0011.jpg',
# ...
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0400.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0414.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0372.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1130.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0548.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1124.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0212.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0574.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0560.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1118.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0206.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0789.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0951.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0945.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0979.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0992.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0038.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0986.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0776.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0010.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0004.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0762.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0739.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0063.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0705.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0711.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0077.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0922.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0936.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0088.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1143.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0249.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1157.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0507.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0261.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0275.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0513.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1180.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1037.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0329.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1023.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0473.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0315.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0301.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0467.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0498.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0895.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0881.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0659.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0117.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0671.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0665.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0103.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0856.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0842.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0843.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0857.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0664.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0102.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0116.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0670.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0658.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0880.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0894.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0499.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0300.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0466.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0472.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0314.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1022.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0328.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1036.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1181.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0274.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0512.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0506.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0260.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1156.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0248.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1142.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0937.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0089.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0923.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0710.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0076.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0062.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0704.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0738.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0048.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0074.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0712.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0706.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0060.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0935.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0921.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0909.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1154.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1140.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0538.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0510.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0276.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1168.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0262.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0504.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0289.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1183.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0458.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1020.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1034.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0464.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0302.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1008.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0316.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0470.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0882.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0896.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0128.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0100.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0666.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0672.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0114.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0699.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0841.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0855.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0869.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0868.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0854.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0840.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0698.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0673.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0115.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0101.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0667.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0897.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0129.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0883.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0317.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1009.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0471.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0465.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0303.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1035.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0459.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1021.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1182.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0288.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0263.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0505.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0511.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1169.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0277.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1141.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0539.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1155.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0908.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0920.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0934.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0707.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0061.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0075.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0713.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0049.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0717.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0071.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0065.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0703.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0059.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0918.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0930.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0924.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0273.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0515.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0501.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0267.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1179.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1151.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0529.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1145.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1192.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1186.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0298.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1019.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0307.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0461.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0475.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0313.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1025.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0449.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1031.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0663.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0105.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0111.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0677.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0887.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0139.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0893.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0878.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0844.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0688.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0850.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0851.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0689.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0845.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0879.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0892.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0886.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0138.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0110.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0676.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0662.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0104.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0448.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1030.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1024.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0474.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0312.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0306.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1018.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0460.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0299.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1187.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1193.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1144.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1150.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0528.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0500.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_1178.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0266.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0272.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0514.jpg',
#  'train_dir/simpsons_dataset/charles_montgomery_burns/pic_0925.jpg',
#  ...]

# %%
CLASS_NAMES = []
for i in os.listdir(train_dir):
    if not i.startswith('.'):
        CLASS_NAMES.append(i)

# %%
def generate_md5_hash(file_path):
    with open(file_path, 'rb') as file:
        # Read the file contents
        data = file.read()

        # Calculate the MD5 hash
        md5_hash = hashlib.md5(data).hexdigest()

        return md5_hash

# %%
def remove_duplicate_from_dir(dir):
    hashes = {}
    files = glob(os.path.join(dir, '*.jpg'))
    for path in files:
        hash_image = generate_md5_hash(path)
        if hash_image not in hashes:
            hashes[hash_image] = []
        hashes[hash_image].append(path)
    duplicate_counter = 0
    for hash, images in hashes.items():
        if len(images) > 1:
            for image in images[1:]:
                os.remove(image)
                duplicate_counter += 1
    if duplicate_counter > 0:
        print(f"removed {duplicate_counter} duplicate from {dir}")

# %%
for dir in glob(os.path.join(train_dir, "*")):
    remove_duplicate_from_dir(dir)

# %%
def items_per_class():
    class_quantity = {i: 0 for i in CLASS_NAMES}
    for class_name in CLASS_NAMES:
        if not class_name.startswith('.'):
            class_path = os.path.join(train_dir, class_name)
            num_images = len(glob(os.path.join(class_path, '*.*')))
            class_quantity[class_name] += num_images
    return class_quantity

# %%
def print_classes_graph():
    class_stat = items_per_class()
    plt.bar(class_stat.keys(), class_stat.values(), align='center')
    plt.xticks(rotation=90)
    print(f"Total classes: {len(class_stat.keys())}")
    print(f"Items per class:")
    for key, value in class_stat.items():
        print(key, value)
    plt.show()


print_classes_graph()
# Out:
# Total classes: 42
# Items per class:
# maggie_simpson 503
# charles_montgomery_burns 1193
# patty_bouvier 504
# ralph_wiggum 504
# chief_wiggum 986
# milhouse_van_houten 1079
# rainier_wolfcastle 506
# cletus_spuckler 506
# martin_prince 505
# lenny_leonard 501
# sideshow_bob 877
# fat_tony 504
# selma_bouvier 503
# barney_gumble 502
# lionel_hutz 192
# gil 504
# moe_szyslak 1452
# carl_carlson 503
# edna_krabappel 501
# snake_jailbird 505
# groundskeeper_willie 501
# sideshow_mel 508
# ned_flanders 1454
# abraham_grampa_simpson 913
# krusty_the_clown 1206
# waylon_smithers 502
# apu_nahasapeemapetilon 623
# marge_simpson 1291
# comic_book_guy 501
# nelson_muntz 501
# mayor_quimby 501
# kent_brockman 501
# professor_john_frink 505
# principal_skinner 1194
# bart_simpson 1342
# lisa_simpson 1354
# otto_mann 512
# troy_mcclure 512
# miss_hoover 502
# disco_stu 512
# homer_simpson 2246
# agnes_skinner 504

# %%
def get_low_quality_classes(left, right):
    low_quantity_classes = []
    class_stat = items_per_class()
    for key, value in class_stat.items():
        if left <= value <= right:
            low_quantity_classes.append(key)
            print(key, value)

    print(f"Classes with items [{left}:{right}] : {len(low_quantity_classes)}")
    print(low_quantity_classes)
    return low_quantity_classes

# %%
def remove_all_augmentations():
    files_augmented = glob(os.path.join(train_dir, '*/aug*.png'))
    for file in files_augmented:
        os.remove(file)
    print("All augmentations removed: ", len(files_augmented))


def remove_all_random_augmentations():
    files_augmented = glob(os.path.join(train_dir, '*/random*.png'))
    for file in files_augmented:
        os.remove(file)
    print("All augmentations removed: ", len(files_augmented))

# remove_all_augmentations()

# %%
def apply_basic_aug():
    flip_transform = transforms.Compose([transforms.PILToTensor(),
                                     transforms.GaussianBlur(kernel_size=(25, 25), sigma=(0.2, 4.0)),
                                     transforms.ToPILImage()])
    blur_transform = transforms.Compose([transforms.PILToTensor(),
                                         transforms.RandomHorizontalFlip(p=1),
                                         transforms.ToPILImage()])
    
    classes = get_low_quality_classes(0, 30)
    
    for class_name in tqdm(classes):
        dir_path = os.path.join(train_dir, class_name)
        pictures = glob(os.path.join(dir_path, '*'))
        pic_number = len(pictures)
        for filename in pictures:
            image = Image.open(filename)
            path = os.path.join(dir_path, f"aug_pic{pic_number}.png")
            blurred = blur_transform(image)
            blurred.save(path)
            pic_number += 1
    print(f"blurred")
    
    for class_name in tqdm(classes):
        dir_path = os.path.join(train_dir, class_name)
        pictures = glob(os.path.join(dir_path, '*'))
        pic_number = len(pictures)
        for filename in pictures:
            image = Image.open(filename)
            path = os.path.join(dir_path, f"aug_pic{pic_number}.png")
            flipped = flip_transform(image)
            flipped.save(path)
            pic_number += 1
    print(f"flipped")
apply_basic_aug()
# Out:
# Classes with items [0:30] : 0
# []
# 0it [00:00, ?it/s]
# blurred
# 0it [00:00, ?it/s]
# flipped

# %%
# remove_all_random_augmentations()

# %%
classes = get_low_quality_classes(0, 500)
if len(classes) == 1:
    classes = []
for class_name in classes:
    dir_path = os.path.join(train_dir, class_name)
    pictures = glob(os.path.join(dir_path, '*'))
    pic_number = len(pictures)
    aug_per_pic = math.ceil((500 - pic_number) / pic_number)
    random_augment_transform = transforms.Compose([transforms.PILToTensor(),
                                                   transforms.RandAugment(num_ops=aug_per_pic + 2),
                                                   transforms.ToPILImage()])
    if aug_per_pic > 15:
        aug_per_pic = 15
    rand = transforms.RandAugment(num_ops=aug_per_pic + 2)
    for filename in tqdm(pictures):
        image = Image.open(filename)

        for i in range(aug_per_pic):
            path = os.path.join(dir_path, f"random_aug_pic{pic_number}.png")
            augmented = rand(image)
            augmented.save(path)
            pic_number += 1
        if pic_number > 500:
            break
# Out:
# lionel_hutz 192
# Classes with items [0:500] : 1
# ['lionel_hutz']

# %%
print_classes_graph()
# Out:
# Total classes: 42
# Items per class:
# maggie_simpson 503
# charles_montgomery_burns 1193
# patty_bouvier 504
# ralph_wiggum 504
# chief_wiggum 986
# milhouse_van_houten 1079
# rainier_wolfcastle 506
# cletus_spuckler 506
# martin_prince 505
# lenny_leonard 501
# sideshow_bob 877
# fat_tony 504
# selma_bouvier 503
# barney_gumble 502
# lionel_hutz 192
# gil 504
# moe_szyslak 1452
# carl_carlson 503
# edna_krabappel 501
# snake_jailbird 505
# groundskeeper_willie 501
# sideshow_mel 508
# ned_flanders 1454
# abraham_grampa_simpson 913
# krusty_the_clown 1206
# waylon_smithers 502
# apu_nahasapeemapetilon 623
# marge_simpson 1291
# comic_book_guy 501
# nelson_muntz 501
# mayor_quimby 501
# kent_brockman 501
# professor_john_frink 505
# principal_skinner 1194
# bart_simpson 1342
# lisa_simpson 1354
# otto_mann 512
# troy_mcclure 512
# miss_hoover 502
# disco_stu 512
# homer_simpson 2246
# agnes_skinner 504

# %%
def calculate_mean_std(filenames):
    num_channels = 3
    dataset_mean = torch.zeros(num_channels)
    dataset_std = torch.zeros(num_channels)
    num_images = len(filenames)
    print('==> Computing mean and std..')
    for filename in tqdm(filenames):
        ToTensor = transforms.ToTensor()
        image_tensor = ToTensor(Image.open(filename))
        for i in range(num_channels):
            dataset_mean[i] += image_tensor[i, :, :].mean()
            dataset_std[i] += image_tensor[i, :, :].std()
    dataset_mean.div_(num_images)
    dataset_std.div_(num_images)
    print(f"Mean: {dataset_mean}")
    print(f"std: {dataset_std}")
    return dataset_mean, dataset_std

# %%
# files_training = list_of_train_files(with_aug=False)
# result = calculate_mean_std(files_training)
total_mean, total_std = torch.tensor([0.4298, 0.3888, 0.3424]), torch.tensor([0.2325, 0.2168, 0.2363])
no_aug_mean, no_aug_std = torch.tensor([0.4622, 0.4075, 0.3524]), torch.tensor([0.2167, 0.1961, 0.2246])

# %%
from sklearn.model_selection import train_test_split
dataset_transform = transforms.Compose([transforms.Resize((256, 256)),
                                        transforms.CenterCrop(224), transforms.ToTensor(),
                                        transforms.Normalize(mean=total_mean, std=total_std)])
images_dataset = datasets.ImageFolder(
    root=train_dir, transform=dataset_transform
)

# %%
num_epochs = 10
batch_size = 16
learning_rate = 0.001
device = "mps"

# %%
from torch.utils.data import SubsetRandomSampler
def get_loaders(dataset):
    length = len(images_dataset)
    indicies = list(range(length))
    train_ind, val_ind = train_test_split(indicies, train_size=0.9, stratify=images_dataset.targets, shuffle=True, random_state=42)
    train_sampler = SubsetRandomSampler(train_ind)
    valid_sampler = SubsetRandomSampler(val_ind)
    
    train_loader = torch.utils.data.DataLoader(images_dataset, batch_size=batch_size, 
                                               sampler=train_sampler)
    validation_loader = torch.utils.data.DataLoader(images_dataset, batch_size=batch_size,
                                                    sampler=valid_sampler)
    return train_loader, validation_loader

# %%
model = torchvision.models.resnet50(pretrained=False)
# Set the model to run on the device
model = model.to(device)

train_loader, validation_loader = get_loaders(images_dataset)

# Define the loss function and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
# Train the model...
for epoch in range(num_epochs):
    print(f"Running {epoch+1} epoch")
    for inputs, labels in tqdm(train_loader):
        # Move input and label tensors to the device
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Zero out the optimizer
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward pass
        loss.backward()
        optimizer.step()

    # Print the loss for every epoch
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {loss.item():.4f}')

print(f'Finished Training, Loss: {loss.item():.4f}')
# Out:
# Running 1 epoch
#   7%|██▉                                     | 130/1745 [01:13<15:09,  1.78it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 18
#      16     # Backward pass
#      17     loss.backward()
# ---> 18     optimizer.step()
#      20 # Print the loss for every epoch
#      21 print(f'Epoch {epoch+1}/{num_epochs}, Loss: {loss.item():.4f}')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/adam.py:166, in Adam.step(self, closure)
#     155     beta1, beta2 = group['betas']
#     157     has_complex = self._init_group(
#     158         group,
#     159         params_with_grad,
#    (...)
#     163         max_exp_avg_sqs,
#     164         state_steps)
# --> 166     adam(
#     167         params_with_grad,
#     168         grads,
#     169         exp_avgs,
#     170         exp_avg_sqs,
#     171         max_exp_avg_sqs,
#     172         state_steps,
#     173         amsgrad=group['amsgrad'],
#     174         has_complex=has_complex,
#     175         beta1=beta1,
#     176         beta2=beta2,
#     177         lr=group['lr'],
#     178         weight_decay=group['weight_decay'],
#     179         eps=group['eps'],
#     180         maximize=group['maximize'],
#     181         foreach=group['foreach'],
#     182         capturable=group['capturable'],
#     183         differentiable=group['differentiable'],
#     184         fused=group['fused'],
#     185         grad_scale=getattr(self, "grad_scale", None),
#     186         found_inf=getattr(self, "found_inf", None),
#     187     )
#     189 return loss
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/adam.py:316, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     313 else:
#     314     func = _single_tensor_adam
# --> 316 func(params,
#     317      grads,
#     318      exp_avgs,
#     319      exp_avg_sqs,
#     320      max_exp_avg_sqs,
#     321      state_steps,
#     322      amsgrad=amsgrad,
#     323      has_complex=has_complex,
#     324      beta1=beta1,
#     325      beta2=beta2,
#     326      lr=lr,
#     327      weight_decay=weight_decay,
#     328      eps=eps,
#     329      maximize=maximize,
#     330      capturable=capturable,
#     331      differentiable=differentiable,
#     332      grad_scale=grad_scale,
#     333      found_inf=found_inf)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/adam.py:391, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     388     param = torch.view_as_real(param)
#     390 # Decay the first and second moment running average coefficient
# --> 391 exp_avg.lerp_(grad, 1 - beta1)
#     392 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     394 if capturable or differentiable:
#
# KeyboardInterrupt:
